# %% [markdown]
# # Comparing the results from the DNN vs. CNN

# %%
import importlib
import cnn_module as module
importlib.reload(module)
import tensorflow as tf
from tensorflow import keras
import os

# %% [markdown]
# ## DNN Model

# %% [markdown]
# ### Load the DNN Model

# %%
dnn_model = keras.models.load_model('mnist_dnn_model.h5')
dnn_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  flatten_2 (Flatten)         (None, 784)               0
#
#  dense_6 (Dense)             (None, 400)               314000
#
#  dense_7 (Dense)             (None, 10)                4010
#
# ...
# Total params: 318010 (1.21 MB)
# Trainable params: 318010 (1.21 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### Predict on the Handwritten digits

# %%
dnn_results = module.predict_all_digits(dnn_model, folder_path='raw_digits')
# Out:
# Processing 10 digit images from raw_digits
#
# Processing image 1/10: raw_digits\handwritten_digit_eight.jpg
# Predicted digit: 3
# Confidence: 57.70%
# Saved visualization to preprocessed_digits\eight\handwritten_digit_eight_prediction.png
# Processing image 2/10: raw_digits\handwritten_digit_five.jpg
# Predicted digit: 5
# Confidence: 100.00%
# Saved visualization to preprocessed_digits\five\handwritten_digit_five_prediction.png
# Processing image 3/10: raw_digits\handwritten_digit_four.jpg
# Predicted digit: 4
# Confidence: 96.88%
# Saved visualization to preprocessed_digits\four\handwritten_digit_four_prediction.png
# Processing image 4/10: raw_digits\handwritten_digit_nine.jpg
# Predicted digit: 9
# Confidence: 35.37%
# Saved visualization to preprocessed_digits\nine\handwritten_digit_nine_prediction.png
# Processing image 5/10: raw_digits\handwritten_digit_one.jpg
# Predicted digit: 1
# Confidence: 100.00%
# ...

# %% [markdown]
# ### Results of the Prediction

# %%
module.analyze_results(dnn_results)
# Out:
# Image: handwritten_digit_eight.jpg, True: 8, Predicted: 3, Confidence: 57.70%
# Image: handwritten_digit_five.jpg, True: 5, Predicted: 5, Confidence: 100.00%
# Image: handwritten_digit_four.jpg, True: 4, Predicted: 4, Confidence: 96.88%
# Image: handwritten_digit_nine.jpg, True: 9, Predicted: 9, Confidence: 35.37%
# Image: handwritten_digit_one.jpg, True: 1, Predicted: 1, Confidence: 100.00%
# Image: handwritten_digit_seven.jpg, True: 7, Predicted: 1, Confidence: 69.55%
# Image: handwritten_digit_six.jpg, True: 6, Predicted: 6, Confidence: 80.99%
# Image: handwritten_digit_three.jpg, True: 3, Predicted: 3, Confidence: 100.00%
# Image: handwritten_digit_two.jpg, True: 2, Predicted: 2, Confidence: 99.96%
# Image: handwritten_digit_zero.jpg, True: 0, Predicted: 0, Confidence: 97.15%
#
# Accuracy: 80.00% (8/10)
# Average confidence: 83.76%

# %% [markdown]
# ## CNN Model

# %% [markdown]
# ### Load the CNN model

# %%
cnn_model = keras.models.load_model('mnist_cnn_model.h5')
cnn_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_6 (Conv2D)           (None, 28, 28, 32)        320
#
#  max_pooling2d_6 (MaxPoolin  (None, 14, 14, 32)        0
#  g2D)
#
#  conv2d_7 (Conv2D)           (None, 14, 14, 64)        18496
#
#  max_pooling2d_7 (MaxPoolin  (None, 7, 7, 64)          0
#  g2D)
#
#  conv2d_8 (Conv2D)           (None, 7, 7, 128)         73856
#
#  max_pooling2d_8 (MaxPoolin  (None, 3, 3, 128)         0
#  g2D)
#
#  flatten_2 (Flatten)         (None, 1152)              0
#
#  dense_4 (Dense)             (None, 128)               147584
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_5 (Dense)             (None, 10)                1290
#
# ...
# Total params: 241546 (943.54 KB)
# Trainable params: 241546 (943.54 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### Prediction on the Handwritten digits

# %%
cnn_results = module.predict_all_digits(cnn_model, folder_path='raw_digits')
# Out:
# Processing 10 digit images from raw_digits
#
# Processing image 1/10: raw_digits\handwritten_digit_eight.jpg
# Predicted digit: 8
# Confidence: 100.00%
# Saved visualization to preprocessed_digits\eight\handwritten_digit_eight_prediction.png
# Processing image 2/10: raw_digits\handwritten_digit_five.jpg
# Predicted digit: 5
# Confidence: 100.00%
# Saved visualization to preprocessed_digits\five\handwritten_digit_five_prediction.png
# Processing image 3/10: raw_digits\handwritten_digit_four.jpg
# Predicted digit: 4
# Confidence: 100.00%
# Saved visualization to preprocessed_digits\four\handwritten_digit_four_prediction.png
# Processing image 4/10: raw_digits\handwritten_digit_nine.jpg
# Predicted digit: 9
# Confidence: 88.90%
# Saved visualization to preprocessed_digits\nine\handwritten_digit_nine_prediction.png
# Processing image 5/10: raw_digits\handwritten_digit_one.jpg
# Predicted digit: 1
# Confidence: 100.00%
# ...

# %% [markdown]
# ### Results of the Prediction

# %%
module.analyze_results(cnn_results)
# Out:
# Image: handwritten_digit_eight.jpg, True: 8, Predicted: 8, Confidence: 100.00%
# Image: handwritten_digit_five.jpg, True: 5, Predicted: 5, Confidence: 100.00%
# Image: handwritten_digit_four.jpg, True: 4, Predicted: 4, Confidence: 100.00%
# Image: handwritten_digit_nine.jpg, True: 9, Predicted: 9, Confidence: 88.90%
# Image: handwritten_digit_one.jpg, True: 1, Predicted: 1, Confidence: 100.00%
# Image: handwritten_digit_seven.jpg, True: 7, Predicted: 7, Confidence: 95.96%
# Image: handwritten_digit_six.jpg, True: 6, Predicted: 6, Confidence: 99.69%
# Image: handwritten_digit_three.jpg, True: 3, Predicted: 3, Confidence: 100.00%
# Image: handwritten_digit_two.jpg, True: 2, Predicted: 2, Confidence: 100.00%
# Image: handwritten_digit_zero.jpg, True: 0, Predicted: 0, Confidence: 100.00%
#
# Accuracy: 100.00% (10/10)
# Average confidence: 98.45%

# %% [markdown]
# ## CNN Exponential learning rate Scheduler

# %%
cnn_exponential_model = keras.models.load_model('exponential_cnn_model.h5')
cnn_exponential_model.summary()
cnn_exponential_results = module.predict_all_digits(cnn_exponential_model, folder_path='raw_digits')
module.analyze_results(cnn_exponential_results)
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_21 (Conv2D)          (None, 28, 28, 32)        320
#
#  max_pooling2d_21 (MaxPooli  (None, 14, 14, 32)        0
#  ng2D)
#
#  conv2d_22 (Conv2D)          (None, 14, 14, 64)        18496
#
#  max_pooling2d_22 (MaxPooli  (None, 7, 7, 64)          0
#  ng2D)
#
#  conv2d_23 (Conv2D)          (None, 7, 7, 128)         73856
#
#  max_pooling2d_23 (MaxPooli  (None, 3, 3, 128)         0
#  ng2D)
#
#  flatten_7 (Flatten)         (None, 1152)              0
#
#  dense_14 (Dense)            (None, 128)               147584
#
#  dropout_7 (Dropout)         (None, 128)               0
#
#  dense_15 (Dense)            (None, 10)                1290
#
# ...
# Total params: 241546 (943.54 KB)
# Trainable params: 241546 (943.54 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
#
# ...

# %% [markdown]
# ## Sample test data from the MNIST

# %%
_,_,test_data = module.preprocess_mnist()
module.sample_and_view_test_data(test_data, num_samples=5)
# Out:
# WARNING:tensorflow:AutoGraph could not transform <function preprocess_mnist.<locals>.<lambda> at 0x000001ADC7A42700> and will run it as-is.
# Cause: could not parse the source code of <function preprocess_mnist.<locals>.<lambda> at 0x000001ADC7A42700>: no matching AST found among candidates:
# # coding=utf-8
# (lambda x, y: ((tf.cast(x, tf.float32) / 255.0), y))
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function preprocess_mnist.<locals>.<lambda> at 0x000001ADC7A42700> and will run it as-is.
# Cause: could not parse the source code of <function preprocess_mnist.<locals>.<lambda> at 0x000001ADC7A42700>: no matching AST found among candidates:
# # coding=utf-8
# (lambda x, y: ((tf.cast(x, tf.float32) / 255.0), y))
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# ...

# %%
model = keras.models.load_model('temp.h5')
model.summary()
temp_results = module.predict_all_digits(model, folder_path='raw_digits')
module.analyze_results(temp_results)
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv1 (Conv2D)              (None, 28, 28, 32)        320
#
#  pool1 (MaxPooling2D)        (None, 14, 14, 32)        0
#
#  conv2 (Conv2D)              (None, 14, 14, 64)        18496
#
#  pool2 (MaxPooling2D)        (None, 7, 7, 64)          0
#
#  conv3 (Conv2D)              (None, 7, 7, 128)         73856
#
#  pool3 (MaxPooling2D)        (None, 3, 3, 128)         0
#
#  flatten (Flatten)           (None, 1152)              0
#
#  dense1 (Dense)              (None, 128)               147584
#
#  dropout (Dropout)           (None, 128)               0
#
#  output (Dense)              (None, 10)                1290
#
# ...
# Total params: 241546 (943.54 KB)
# Trainable params: 241546 (943.54 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
#
# ...
